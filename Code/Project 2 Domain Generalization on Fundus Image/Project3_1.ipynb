# %% [markdown]
# # Import library and find directory

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorboardX==2.0
# !pip install opencv-python
# !pip install pyyaml
# !pip install MedPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.7/195.7 kB 6.2 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.8/151.8 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 MB 18.8 MB/s eta 0:00:00
# ...
#   Created wheel for MedPy: filename=MedPy-0.4.0-py3-none-any.whl size=214946 sha256=85cb1d0c2c57b4971ccb28a5d4da03461b96d96396538dcefdb57e96ff63efa3
#   Stored in directory: /root/.cache/pip/wheels/d4/32/c7/6380ab2edb8cca018d39a0f1d43250fd9791922c963117de46
# Successfully built MedPy
# ...

# %%
cd /content/drive/MyDrive/Dofe-master
# Out:
# /content/drive/MyDrive/Dofe-master

# %% [markdown]
# #Baseline for testing domain 4

# %%
# !python train-baseline.py -g 0 --datasetTrain 1 2 3 --datasetTest 4 --batch-size 16 --data-dir ./Fundus/ --max-epoch 40
# Out:
# ==> Loading train data from: ./Fundus/Domain1/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain2/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain3/train/ROIs/image/
# -----Total number of images in train: 469
# ==> Loading test data from: ./Fundus/Domain4/test/ROIs/image/
# -----Total number of images in test: 80
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100% 170M/170M [00:00<00:00, 255MB/s]
# parameter numer: 63170119
# ...
# Train epoch=0: 100%|████████████████████████████| 20/20 [00:41<00:00,  1.68s/it]
#
# [Epoch: 0] lr:0.001000,  Average segLoss: 0.229669, Average clsLoss: 0.004188, Execution time: 41.83829
#
# ...
# Train epoch=1: 100%|████████████████████████████| 20/20 [00:35<00:00,  1.75s/it]
#
# [Epoch: 1] lr:0.001000,  Average segLoss: 0.056417, Average clsLoss: 0.001222, Execution time: 35.86508
# ...

# %%
# !python test-baseline.py --model-file ./logs/test4/lam0.9/20230525_004702.253882/checkpoint_40.pth.tar --datasetTest 4 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain4/test/ROIs/image/
# -----Total number of images in test: 80
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100% 170M/170M [00:00<00:00, 218MB/s]
# ==> Loading DeepLab model file: ./logs/test4/lam0.9/20230525_004702.253882/checkpoint_40.pth.tar
#   0%|                                                     | 0/7 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test-baseline.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# # Train on 1, 2, 3 and test on 4

# %%
# !python train.py -g 0 --datasetTrain 1 2 3 --datasetTest 4 --batch-size 16 --resume ./pretrained-weight/test4-epoch40.pth.tar --data-dir ./Fundus/ # You need to pretrain a model
# Out:
# ==> Loading train data from: ./Fundus/Domain1/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain2/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain3/train/ROIs/image/
# -----Total number of images in train: 469
# ==> Loading test data from: ./Fundus/Domain4/test/ROIs/image/
# -----Total number of images in test: 80
# Downloading: "http://jeff95.me/models/mobilenet_v2-6a65762b.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-6a65762b.pth
# 100% 8.66M/8.66M [00:02<00:00, 3.92MB/s]
# parameter numer: 9641863
# Before  tensor([[[[ 4.1071e-01, -5.6623e-01,  3.7223e-01,  ..., -2.7944e-01,
#            -7.3782e-02, -2.4528e-01],
#           [ 1.2157e+00, -2.9202e-01,  1.3380e+00,  ..., -1.5858e-02,
#             1.5694e+00, -4.3429e-02],
#           [ 6.4272e-01, -6.7525e-01,  1.7909e+00,  ..., -8.6947e-01,
#             1.3147e+00,  1.2774e+00],
#           ...,
#           [ 1.5878e+00, -6.2611e-01, -4.2276e-01,  ...,  1.0760e+00,
# ...

# %%
# !python test.py --model-file ./logs/test4/lam0.9/20230521_181051.475399/checkpoint_80.pth.tar --datasetTest 4 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain4/test/ROIs/image/
# -----Total number of images in test: 80
# ==> Loading DeepLab model file: ./logs/test4/lam0.9/20230521_181051.475399/checkpoint_80.pth.tar
#   0%|                                                     | 0/7 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# #Baseline for testing domain 3

# %%
# !python train-baseline.py -g 0 --datasetTrain 1 2 4 --datasetTest 3 --batch-size 16 --data-dir ./Fundus/ --stop-epoch 40
# Out:
# ==> Loading train data from: ./Fundus/Domain1/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain2/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain4/train/ROIs/image/
# -----Total number of images in train: 469
# ==> Loading test data from: ./Fundus/Domain3/test/ROIs/image/
# -----Total number of images in test: 80
# parameter numer: 63170119
# ...
# Train epoch=0: 100%|████████████████████████████| 20/20 [00:37<00:00,  1.77s/it]
#
# [Epoch: 0] lr:0.001000,  Average segLoss: 0.226116, Average clsLoss: 0.004475, Execution time: 37.93843
#
# ...
# Train epoch=1: 100%|████████████████████████████| 20/20 [00:37<00:00,  1.85s/it]
#
# [Epoch: 1] lr:0.001000,  Average segLoss: 0.048733, Average clsLoss: 0.001238, Execution time: 37.96685
# ...
# Train epoch=2: 100%|████████████████████████████| 20/20 [00:39<00:00,  1.91s/it]
#
# [Epoch: 2] lr:0.001000,  Average segLoss: 0.035436, Average clsLoss: 0.000801, Execution time: 39.43653
# ...

# %%
# !python test-baseline.py --model-file ./logs/test3/lam0.9/20230525_011914.176291/checkpoint_40.pth.tar --datasetTest 3 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain3/test/ROIs/image/
# -----Total number of images in test: 80
# ==> Loading DeepLab model file: ./logs/test3/lam0.9/20230525_011914.176291/checkpoint_40.pth.tar
#   0%|                                                     | 0/7 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test-baseline.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# #Train on 1, 2, 4 test on 3

# %%
# !python train.py -g 0 --datasetTrain 1 2 4 --datasetTest 3 --batch-size 16 --resume ./pretrained-weight/test4-epoch40.pth.tar --data-dir ./Fundus/ # You need to pretrain a model
# Out:
# ==> Loading train data from: ./Fundus/Domain1/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain2/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain4/train/ROIs/image/
# -----Total number of images in train: 469
# ==> Loading test data from: ./Fundus/Domain3/test/ROIs/image/
# -----Total number of images in test: 80
# Downloading: "http://jeff95.me/models/mobilenet_v2-6a65762b.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-6a65762b.pth
# 100% 8.66M/8.66M [00:00<00:00, 92.8MB/s]
# parameter numer: 9641863
# Before  tensor([[[[ 5.8284e-01, -3.3020e-03, -1.9476e+00,  ...,  8.9866e-01,
#            -3.8611e-01,  4.1243e-01],
#           [ 5.0614e-01, -1.5697e+00,  9.3992e-01,  ...,  1.0572e+00,
#             3.5699e-01,  1.1874e+00],
#           [-8.5785e-02,  4.8669e-01,  2.3877e+00,  ..., -1.6185e+00,
#             2.0588e-01,  7.4265e-01],
#           ...,
#           [-8.0703e-02,  1.0725e+00,  7.4553e-01,  ..., -3.0850e-01,
# ...

# %%
# !python test.py --model-file ./logs/test3/lam0.9/20230522_125035.573135/checkpoint_80.pth.tar --datasetTest 3 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain3/test/ROIs/image/
# -----Total number of images in test: 80
# ==> Loading DeepLab model file: ./logs/test3/lam0.9/20230522_125035.573135/checkpoint_80.pth.tar
#   0%|                                                     | 0/7 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# #Baseline for testing domain 2

# %%
# !python train-baseline.py -g 0 --datasetTrain 1 3 4 --datasetTest 2 --batch-size 16 --data-dir ./Fundus/ --max-epoch 40
# Out:
# ==> Loading train data from: ./Fundus/Domain1/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain3/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain4/train/ROIs/image/
# -----Total number of images in train: 690
# ==> Loading test data from: ./Fundus/Domain2/test/ROIs/image/
# -----Total number of images in test: 60
# parameter numer: 63170119
# ...
# Train epoch=0: 100%|████████████████████████████| 20/20 [00:37<00:00,  1.74s/it]
#
# [Epoch: 0] lr:0.001000,  Average segLoss: 0.225746, Average clsLoss: 0.006555, Execution time: 37.76885
#
# ...
# Train epoch=1: 100%|████████████████████████████| 20/20 [00:36<00:00,  1.79s/it]
#
# [Epoch: 1] lr:0.001000,  Average segLoss: 0.051424, Average clsLoss: 0.000910, Execution time: 36.69144
# ...
# Train epoch=2: 100%|████████████████████████████| 20/20 [00:37<00:00,  1.82s/it]
#
# [Epoch: 2] lr:0.001000,  Average segLoss: 0.035635, Average clsLoss: 0.000748, Execution time: 37.52359
# ...

# %%
# !python test-baseline.py --model-file ./logs/test2/lam0.9/20230525_071906.214519/checkpoint_40.pth.tar --datasetTest 2 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain2/test/ROIs/image/
# -----Total number of images in test: 60
# ==> Loading DeepLab model file: ./logs/test2/lam0.9/20230525_071906.214519/checkpoint_40.pth.tar
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test-baseline.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# #Train on 1, 3, 4 Test on 2

# %%
# !python train.py -g 0 --datasetTrain 1 3 4 --datasetTest 2 --batch-size 16 --resume ./pretrained-weight/test4-epoch40.pth.tar --data-dir ./Fundus/ # You need to pretrain a model
# Out:
# ==> Loading train data from: ./Fundus/Domain1/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain3/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain4/train/ROIs/image/
# -----Total number of images in train: 690
# ==> Loading test data from: ./Fundus/Domain2/test/ROIs/image/
# -----Total number of images in test: 60
# Downloading: "http://jeff95.me/models/mobilenet_v2-6a65762b.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-6a65762b.pth
# 100% 8.66M/8.66M [00:02<00:00, 3.91MB/s]
# parameter numer: 9641863
# Before  tensor([[[[-1.7198e-01,  1.1454e+00, -1.0042e-01,  ..., -3.0055e-02,
#            -1.5395e+00,  1.0613e+00],
#           [ 7.9467e-01,  5.3533e-01,  1.5001e+00,  ...,  9.0277e-01,
#            -1.1725e+00, -2.7689e+00],
#           [-8.8011e-01, -1.1159e+00, -4.6155e-01,  ..., -2.2327e+00,
#             5.4920e-01, -2.8200e-01],
#           ...,
#           [-1.9902e+00,  8.7916e-03, -5.0123e-01,  ...,  5.0701e-02,
# ...

# %%
# !python test.py --model-file ./logs/test2/lam0.9/20230522_131055.871033/checkpoint_80.pth.tar --datasetTest 2 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain2/test/ROIs/image/
# -----Total number of images in test: 60
# Downloading: "http://jeff95.me/models/mobilenet_v2-6a65762b.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-6a65762b.pth
# 100% 8.66M/8.66M [00:00<00:00, 37.4MB/s]
# ==> Loading DeepLab model file: ./logs/test2/lam0.9/20230522_131055.871033/checkpoint_80.pth.tar
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# #Baseline for testing domain 1

# %%
# !python train-baseline.py -g 0 --datasetTrain 2 3 4 --datasetTest 1 --batch-size 16 --data-dir ./Fundus/ --max-epoch 40
# Out:
# ==> Loading train data from: ./Fundus/Domain2/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain3/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain4/train/ROIs/image/
# -----Total number of images in train: 739
# ==> Loading test data from: ./Fundus/Domain1/test/ROIs/image/
# -----Total number of images in test: 51
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# 100% 170M/170M [00:01<00:00, 103MB/s]
# parameter numer: 63170119
# ...
# Train epoch=0: 100%|████████████████████████████| 20/20 [00:42<00:00,  1.72s/it]
#
# [Epoch: 0] lr:0.001000,  Average segLoss: 0.239363, Average clsLoss: 0.003128, Execution time: 42.26673
#
# ...
# Train epoch=1: 100%|████████████████████████████| 20/20 [00:36<00:00,  1.76s/it]
#
# [Epoch: 1] lr:0.001000,  Average segLoss: 0.055505, Average clsLoss: 0.000837, Execution time: 36.52452
# ...

# %%
# !python test-baseline.py --model-file ./logs/test1/lam0.9/20230525_064753.387050/checkpoint_40.pth.tar --datasetTest 1 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain1/test/ROIs/image/
# -----Total number of images in test: 51
# ==> Loading DeepLab model file: ./logs/test1/lam0.9/20230525_064753.387050/checkpoint_40.pth.tar
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test-baseline.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...

# %% [markdown]
# #Train on 2, 3, 4, test on 1

# %%
# !python train.py -g 0 --datasetTrain 2 3 4 --datasetTest 1 --batch-size 16 --resume ./pretrained-weight/test4-epoch40.pth.tar --data-dir ./Fundus/ # You need to pretrain a model
# Out:
# ==> Loading train data from: ./Fundus/Domain2/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain3/train/ROIs/image/
# ==> Loading train data from: ./Fundus/Domain4/train/ROIs/image/
# -----Total number of images in train: 739
# ==> Loading test data from: ./Fundus/Domain1/test/ROIs/image/
# -----Total number of images in test: 51
# parameter numer: 9641863
# Before  tensor([[[[-8.2940e-01, -1.7829e+00,  1.3023e-01,  ...,  1.8624e-01,
#             3.9467e-01,  8.0211e-01],
#           [ 5.7656e-02, -7.2056e-01,  2.2415e+00,  ...,  1.5510e-01,
#            -1.3369e+00,  4.0463e-01],
#           [-2.3151e+00,  7.6911e-01, -5.3343e-02,  ...,  6.7026e-01,
#             4.9071e-01,  1.0356e+00],
#           ...,
#           [ 1.6226e+00, -6.2122e-01, -1.2860e+00,  ..., -1.1015e-01,
#            -8.8398e-01,  4.9847e-01],
#           [ 1.7078e+00,  3.3107e+00,  2.6364e-01,  ...,  5.6688e-01,
#             1.4072e-01,  6.4639e-01],
# ...

# %%
# !python test.py --model-file ./logs/test1/lam0.9/20230522_132020.279815/checkpoint_80.pth.tar --datasetTest 1 -g 0 --data-dir ./Fundus/
# Out:
# ==> Loading test data from: ./Fundus/Domain1/test/ROIs/image/
# -----Total number of images in test: 51
# ==> Loading DeepLab model file: ./logs/test1/lam0.9/20230522_132020.279815/checkpoint_80.pth.tar
#   0%|                                                     | 0/5 [00:00<?, ?it/s]/content/drive/MyDrive/Dofe-master/test.py:204: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   hd_OC = binary.hd95(np.asarray(prediction_post[0, ...], dtype=np.bool),
# ...
